# %% [markdown]
# # RAG Evaluation Demo
#
# ## Purpose of evaluation
# This notebook outlines a practical manual evaluation approach for NeuroPaperRAG.

# %% [markdown]
# ## Example questions
# - What is representational alignment in communication?
# - How do researchers define shared meaning?
# - What methods are used to study dyadic interaction?
# - What does the literature say about autism and communication?

# %% [markdown]
# ## Manual evaluation criteria
# - Retrieval relevance
# - Answer faithfulness
# - Source correctness
# - Hallucination risk
